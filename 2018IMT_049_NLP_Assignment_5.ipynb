# %% [markdown]
# <a href="https://colab.research.google.com/github/madhu1404/NLP-Assigments/blob/main/2018IMT_049_NLP_Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> NLP Assignment-5  <br />
# ### Name - P Madhu Chandra
# ### Roll No - 2018IMT-049

# %%
import nltk
from nltk import word_tokenize
from nltk.corpus import brown

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
nltk.download('brown') 
nltk.download('universal_tagset')


text_news = nltk.Text(word.lower() for word in nltk.corpus.brown.words(categories='news'))
tagged_words= nltk.pos_tag(text_news)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.

# %%
tagged_words
# Out:
# [('the', 'DT'),
#  ('fulton', 'NN'),
#  ('county', 'NN'),
#  ('grand', 'JJ'),
#  ('jury', 'NN'),
#  ('said', 'VBD'),
#  ('friday', 'PDT'),
#  ('an', 'DT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("atlanta's", 'JJ'),
#  ('recent', 'JJ'),
#  ('primary', 'JJ'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'DT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'IN'),
#  ('any', 'DT'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('jury', 'NN'),
#  ('further', 'RB'),
#  ('said', 'VBD'),
#  ('in', 'IN'),
#  ('term-end', 'JJ'),
#  ('presentments', 'NNS'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('executive', 'NN'),
#  ('committee', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('had', 'VBD'),
#  ('over-all', 'JJ'),
#  ('charge', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('election', 'NN'),
#  (',', ','),
#  ('``', '``'),
#  ('deserves', 'VBZ'),
#  ('the', 'DT'),
# ...
